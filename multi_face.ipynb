# %% [markdown]
# ## FACE EMOTION -MULTICLASS CLASSIFICATION

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,MaxPooling2D,Flatten,Dense,Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam,SGD,RMSprop
import matplotlib.pyplot as plt

# %% [markdown]
# ### IMAGE PREPROCESSING

# %%
img_size=150
batch_size=32

train_datagen=ImageDataGenerator(rescale=1./255,
                                 shear_range=0.2,
                                 zoom_range=0.2,
                                 horizontal_flip=True)

val_datagen=ImageDataGenerator(rescale=1./255)
test_datagen=ImageDataGenerator(rescale=1./255)

train_generator=train_datagen.flow_from_directory(r"C:\Users\Pc\OneDrive\Desktop\Deep Learning\CNN MULTICLASS\FACE_DATA\train",
                                                  target_size=(img_size,img_size),
                                                  batch_size=batch_size,
                                                  class_mode='categorical')

val_generator=val_datagen.flow_from_directory(r"C:\Users\Pc\OneDrive\Desktop\Deep Learning\CNN MULTICLASS\FACE_DATA\val",
                                                  target_size=(img_size,img_size),
                                                  batch_size=batch_size,
                                                  class_mode='categorical')

test_generator=test_datagen.flow_from_directory(r"C:\Users\Pc\OneDrive\Desktop\Deep Learning\CNN MULTICLASS\FACE_DATA\test",
                                                  target_size=(img_size,img_size),
                                                  batch_size=batch_size,
                                                  class_mode='categorical')
# Out:
# Found 41367 images belonging to 5 classes.
# Found 8865 images belonging to 5 classes.
# Found 8867 images belonging to 5 classes.

# %% [markdown]
# ### MODEL ARCHITECTURE

# %%
from tensorflow.keras.layers import *
from tensorflow.keras.models import Sequential

model = Sequential([
    Conv2D(32, (3,3), activation='relu', padding='same', input_shape=(150,150,3)),
    BatchNormalization(),
    MaxPooling2D(2,2),

    Conv2D(64, (3,3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling2D(2,2),

    Conv2D(128, (3,3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling2D(2,2),

    Conv2D(256, (3,3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling2D(2,2),

    Flatten(),
    Dense(256, activation='relu'),
    Dropout(0.5),
    Dense(5, activation='softmax')
])
# Out:
# c:\Users\Pc\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# ### COMBILE THE MODEL

# %%
model.compile(
    optimizer = Adam(learning_rate=0.0001),    #how much fast the model learn
    loss='categorical_crossentropy',
    metrics=['accuracy','precision','recall']
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 150, 150, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 150, 150, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 75, 75, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 75, 75, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %% [markdown]
# ### TRAIN THE MODEL

# %%
history = model.fit(
    train_generator,
    epochs=10,      #how many times the model train
    validation_data=val_generator,
    validation_steps=val_generator.samples // batch_size)
# Out:
# Epoch 1/10
# 1293/1293 ━━━━━━━━━━━━━━━━━━━━ 897s 691ms/step - accuracy: 0.3851 - loss: 1.4601 - precision: 0.6282 - recall: 0.1378 - val_accuracy: 0.4838 - val_loss: 1.2711 - val_precision: 0.8329 - val_recall: 0.1777
# Epoch 2/10
# 1293/1293 ━━━━━━━━━━━━━━━━━━━━ 912s 706ms/step - accuracy: 0.4579 - loss: 1.2771 - precision: 0.7507 - recall: 0.2216 - val_accuracy: 0.5452 - val_loss: 1.1319 - val_precision: 0.8156 - val_recall: 0.2759
# Epoch 3/10
# 1064/1293 ━━━━━━━━━━━━━━━━━━━━ 2:49 739ms/step - accuracy: 0.4989 - loss: 1.2015 - precision: 0.7636 - recall: 0.2710
# ---------------------------------------------------------------------------
# UnknownError                              Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 history = model.fit(
#       2     train_generator,
#       3     epochs=10,      #how many times the model train
#       4     validation_data=val_generator,
#       5     validation_steps=val_generator.samples // batch_size)
#
# ...

# %% [markdown]
# ### EVALUATION ON TEST DATA

# %%
loss,acc,prec,recall=model.evaluate(test_generator)
print(f"Test acc :",acc)
# Out:
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 32s 114ms/step - accuracy: 0.1720 - loss: 1.6261 - precision: 0.0000e+00 - recall: 0.0000e+00
# Test acc : 0.17198601365089417

# %%
model.evaluate(test_generator)
# Out:
# 278/278 ━━━━━━━━━━━━━━━━━━━━ 21s 76ms/step - accuracy: 0.6945 - loss: 0.7921 - precision: 0.8119 - recall: 0.5429
# [0.7921369671821594, 0.6944851875305176, 0.8119413256645203, 0.542911946773529]

# %%
import numpy as np
from tensorflow.keras.preprocessing import image

img=image.load_img(r"C:\Users\Pc\OneDrive\Desktop\Deep Learning\CNN MULTICLASS\FACE_DATA\test\Angry\74.png")
img_array=image.img_to_array(img)/255.0
img_array=np.expand_dims(img_array,axis=0)

prediction=model.predict(img_array)
classes=list(train_generator.class_indicates.keys())
print("Predicted emotion:",classes[np.argmax(prediction)])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 8
#       5 img_array=image.img_to_array(img)/255.0
#       6 img_array=np.expand_dims(img_array,axis=0)
# ----> 8 prediction=model.predict(img_array)
#       9 classes=list(train_generator.class_indicates.keys())
#      10 print("Predicted emotion:",classes[np.argmax(prediction)])
#
# File c:\Users\Pc\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# ...
